# %%
import os
from ultralytics import YOLO
import torch
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader

# %%
def list_files(directory):
  try:
    filenames = os.listdir(directory)
    return filenames
  except FileNotFoundError:
    return []

# %%
yolo = YOLO("./paras_yolo_malli/mika_best.pt")
dense_models = list_files("./paras_dense_malli")
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

#val_data = datasets.ImageFolder('datasets/materials/images/validation')
val_loader = DataLoader('datasets/materials/images/validation', batch_size=32, shuffle=False)
print(dense_models)

# %%
for batch in val_loader:
    print(type(batch))
    print(batch)

# %%
for node in dense_models:
    print(node)
    model = YOLO("./paras_yolo_malli/" + node)
    model.val()
    input()
